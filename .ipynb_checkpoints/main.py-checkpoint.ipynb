# %%
from twitter_scraper_helmi import get_tweets

print('z')
data = []
error = 0
for t in get_tweets('fadlizon', pages=50):
    data.append(t)
    if (t['status'] != 'ok'):
        error += 1
    
print('tweet found: ', len(data))
print('error: ', error)
# Out:
# z
# progress: 0.0 %
# progress: 2.0 %
# progress: 4.0 %
# progress: 6.0 %
# progress: 8.0 %
# progress: 10.0 %
# progress: 12.0 %
# progress: 14.000000000000002 %
# progress: 16.0 %
# progress: 18.0 %
# progress: 20.0 %
# progress: 22.0 %
# progress: 24.0 %
# progress: 26.0 %
# progress: 28.000000000000004 %
# progress: 30.0 %
# progress: 32.0 %
# progress: 34.0 %
# progress: 36.0 %
# progress: 38.0 %
# progress: 40.0 %
# progress: 42.0 %
# progress: 44.0 %
# progress: 46.0 %
# progress: 48.0 %
# progress: 50.0 %
# progress: 52.0 %
# progress: 54.0 %
# progress: 56.00000000000001 %
# progress: 57.99999999999999 %
# progress: 60.0 %
# progress: 62.0 %
# progress: 64.0 %
# progress: 66.0 %
# progress: 68.0 %
# progress: 70.0 %
# progress: 72.0 %
# progress: 74.0 %
# progress: 76.0 %
# progress: 78.0 %
# progress: 80.0 %
# progress: 82.0 %
# progress: 84.0 %
# progress: 86.0 %
# progress: 88.0 %
# progress: 90.0 %
# progress: 92.0 %
# progress: 94.0 %
# progress: 96.0 %
# ...

# %%
for i, t in enumerate(data):
    print(t['tweet']['text'])
# Out:
# Gus Irfan Cucu dari Pendiri NU jadi Juru Bicara Baru bagi Prabowo-Sandi, Fadli Zon Angkat Bicara http://medan.tribunnews.com/2018/11/02/gus-irfan-cucu-dari-pendiri-nu-jadi-juru-bicara-baru-bagi-prabowo-sandi-fadli-zon-angkat-bicara …
# Fadli Zon Sambut Baik Kehadiran Cucu Pendiri NU di Tim Prabowo | FAJAR – https://fajar.co.id/?p=387481
#  http://m.rri.co.id/post/berita/592736/politik/fadli_zon_parlemen_miliki_peran_penting_dalam_wujudkan_pemberantasan_korupsi.html …
# Fadli Zon Sambut Baik Kehadiran Cucu Pendiri NU Di Tim Prabowo  https://rmol.co/amp/2018/11/02/364499/Fadli-Zon-Sambut-Baik-Kehadiran-Cucu-Pendiri-NU-Di-Tim-Prabowo- …
# Putra dari Hasyim Asyari Gabung Kubu Prabowo, Fadli Zon Beberkan Posisinya  https://jabar.pojoksatu.id/bandung/2018/11/02/putra-dari-hasyim-asyari-gabung-kubu-prabowo-fadli-zon-beberkan-posisinya/ … @PojokSatu
# ...
